# %% [markdown]
# # **Week 03**

# %%
# Dataframe ---> collection of columns



# 'conventions'
# -> columns should be named
# -> data stored can be of different types
# -> each column should contain same no of data items


# Tibbles -> In tidyverse, tibbles are like streamlined data frames.
        # -> never change the name of your variables
        # -> never change the data types of the input
        # -> never create row names
        # -> make printing easier
        
# Tidy Data -> a way of standardizing and organization of data within R

# %%
library(ggplot2)
data(diamonds)

# %%
View(diamonds)
# Out:
#       carat cut       color clarity depth table price x    y    z
# 1     0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2     0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3     0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4     0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5     0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6     0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# 7     0.24  Very Good I     VVS1    62.3  57    336   3.95 3.98 2.47
# 8     0.26  Very Good H     SI1     61.9  55    337   4.07 4.11 2.53
# 9     0.22  Fair      E     VS2     65.1  61    337   3.87 3.78 2.49
# 10    0.23  Very Good H     VS1     59.4  61    338   4.00 4.05 2.39
# 11    0.30  Good      J     SI1     64.0  55    339   4.25 4.28 2.73
# 12    0.23  Ideal     J     VS1     62.8  56    340   3.93 3.90 2.46
# 13    0.22  Premium   F     SI1     60.4  61    342   3.88 3.84 2.33
# ...

# %%
head(diamonds)
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48

# %%
str(diamonds) # structure of the data
# Out:
# tibble [53,940 x 10] (S3: tbl_df/tbl/data.frame)
#  $ carat  : num [1:53940] 0.23 0.21 0.23 0.29 0.31 0.24 0.24 0.26 0.22 0.23 ...
#  $ cut    : Ord.factor w/ 5 levels "Fair"<"Good"<..: 5 4 2 4 2 3 3 3 1 3 ...
#  $ color  : Ord.factor w/ 7 levels "D"<"E"<"F"<"G"<..: 2 2 2 6 7 7 6 5 2 5 ...
#  $ clarity: Ord.factor w/ 8 levels "I1"<"SI2"<"SI1"<..: 2 3 5 4 2 6 7 3 4 5 ...
#  $ depth  : num [1:53940] 61.5 59.8 56.9 62.4 63.3 62.8 62.3 61.9 65.1 59.4 ...
#  $ table  : num [1:53940] 55 61 65 58 58 57 57 55 61 61 ...
#  $ price  : int [1:53940] 326 326 327 334 335 336 336 337 337 338 ...
#  $ x      : num [1:53940] 3.95 3.89 4.05 4.2 4.34 3.94 3.95 4.07 3.87 4 ...
#  $ y      : num [1:53940] 3.98 3.84 4.07 4.23 4.35 3.96 3.98 4.11 3.78 4.05 ...
#  $ z      : num [1:53940] 2.43 2.31 2.31 2.63 2.75 2.48 2.47 2.53 2.49 2.39 ...

# %%
colnames(diamonds)
# Out:
#  [1] "carat"   "cut"     "color"   "clarity" "depth"   "table"   "price"
#  [8] "x"       "y"       "z"

# %%
library(tidyverse)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.3.2 --
# v tibble  3.1.8     v dplyr   1.1.0
# v tidyr   1.3.0     v stringr 1.5.0
# v readr   2.1.4     v forcats 1.0.0
# v purrr   1.0.1
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
mutate(diamonds, carat_2= carat*100) # to mutate the dataframe , create new column 'carat_2'   (dplyr)
# Out:
#       carat cut       color clarity depth table price x    y    z    carat_2
# 1     0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43 23
# 2     0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31 21
# 3     0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31 23
# 4     0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63 29
# 5     0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75 31
# 6     0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48 24
# 7     0.24  Very Good I     VVS1    62.3  57    336   3.95 3.98 2.47 24
# 8     0.26  Very Good H     SI1     61.9  55    337   4.07 4.11 2.53 26
# 9     0.22  Fair      E     VS2     65.1  61    337   3.87 3.78 2.49 22
# 10    0.23  Very Good H     VS1     59.4  61    338   4.00 4.05 2.39 23
# 11    0.30  Good      J     SI1     64.0  55    339   4.25 4.28 2.73 30
# 12    0.23  Ideal     J     VS1     62.8  56    340   3.93 3.90 2.46 23
# ...

# %%
as_tibble(diamonds)
# Out:
#       carat cut       color clarity depth table price x    y    z
# 1     0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2     0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3     0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4     0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5     0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6     0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# 7     0.24  Very Good I     VVS1    62.3  57    336   3.95 3.98 2.47
# 8     0.26  Very Good H     SI1     61.9  55    337   4.07 4.11 2.53
# 9     0.22  Fair      E     VS2     65.1  61    337   3.87 3.78 2.49
# 10    0.23  Very Good H     VS1     59.4  61    338   4.00 4.05 2.39
# 11    0.30  Good      J     SI1     64.0  55    339   4.25 4.28 2.73
# 12    0.23  Ideal     J     VS1     62.8  56    340   3.93 3.90 2.46
# 13    0.22  Premium   F     SI1     60.4  61    342   3.88 3.84 2.33
# ...

# %%
data()
# Out:
# Data sets in package 'datasets':
#
# AirPassengers           Monthly Airline Passenger Numbers 1949-1960
# BJsales                 Sales Data with Leading Indicator
# BJsales.lead (BJsales)
#                         Sales Data with Leading Indicator
# BOD                     Biochemical Oxygen Demand
# CO2                     Carbon Dioxide Uptake in Grass Plants
# ChickWeight             Weight versus age of chicks on different diets
# DNase                   Elisa assay of DNase
# EuStockMarkets          Daily Closing Prices of Major European Stock
#                         Indices, 1991-1998
# Formaldehyde            Determination of Formaldehyde
# HairEyeColor            Hair and Eye Color of Statistics Students
# Harman23.cor            Harman Example 2.3
# Harman74.cor            Harman Example 7.4
# Indometh                Pharmacokinetics of Indomethacin
# InsectSprays            Effectiveness of Insect Sprays
# ...

# %%
data(mtcars)
mtcars
# Out:
#                     mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# Mazda RX4           21.0 6   160.0 110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag       21.0 6   160.0 110 3.90 2.875 17.02 0  1  4    4
# Datsun 710          22.8 4   108.0  93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive      21.4 6   258.0 110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout   18.7 8   360.0 175 3.15 3.440 17.02 0  0  3    2
# Valiant             18.1 6   225.0 105 2.76 3.460 20.22 1  0  3    1
# Duster 360          14.3 8   360.0 245 3.21 3.570 15.84 0  0  3    4
# Merc 240D           24.4 4   146.7  62 3.69 3.190 20.00 1  0  4    2
# Merc 230            22.8 4   140.8  95 3.92 3.150 22.90 1  0  4    2
# Merc 280            19.2 6   167.6 123 3.92 3.440 18.30 1  0  4    4
# Merc 280C           17.8 6   167.6 123 3.92 3.440 18.90 1  0  4    4
# Merc 450SE          16.4 8   275.8 180 3.07 4.070 17.40 0  0  3    3
# Merc 450SL          17.3 8   275.8 180 3.07 3.730 17.60 0  0  3    3
# ...

# %%
readr_example()
# Out:
#  [1] "challenge.csv"               "chickens.csv"
#  [3] "epa78.txt"                   "example.log"
#  [5] "fwf-sample.txt"              "massey-rating.txt"
#  [7] "mini-gapminder-africa.csv"   "mini-gapminder-americas.csv"
#  [9] "mini-gapminder-asia.csv"     "mini-gapminder-europe.csv"
# [11] "mini-gapminder-oceania.csv"  "mtcars.csv"
# [13] "mtcars.csv.bz2"              "mtcars.csv.zip"
# [15] "whitespace-sample.txt"

# %%
read_csv(readr_example("mtcars.csv"))
# Out:
# Rows: 32 Columns: 11
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# dbl (11): mpg, cyl, disp, hp, drat, wt, qsec, vs, am, gear, carb
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
#    mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# 1  21.0 6   160.0 110 3.90 2.620 16.46 0  1  4    4
# 2  21.0 6   160.0 110 3.90 2.875 17.02 0  1  4    4
# 3  22.8 4   108.0  93 3.85 2.320 18.61 1  1  4    1
# 4  21.4 6   258.0 110 3.08 3.215 19.44 1  0  3    1
# 5  18.7 8   360.0 175 3.15 3.440 17.02 0  0  3    2
# 6  18.1 6   225.0 105 2.76 3.460 20.22 1  0  3    1
# 7  14.3 8   360.0 245 3.21 3.570 15.84 0  0  3    4
# 8  24.4 4   146.7  62 3.69 3.190 20.00 1  0  4    2
# 9  22.8 4   140.8  95 3.92 3.150 22.90 1  0  4    2
# 10 19.2 6   167.6 123 3.92 3.440 18.30 1  0  4    4
# ...

# %% [markdown]
# ## Cleaning Data

# %%
# install.packages('here')
# Out:
# package 'here' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\deepa\AppData\Local\Temp\RtmpiKYtIr\downloaded_packages

# %%
# install.packages('skimr')
# Out:
# package 'skimr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\deepa\AppData\Local\Temp\RtmpiKYtIr\downloaded_packages

# %%
# install.packages('janitor')
# Out:
# also installing the dependency 'snakecase'
# package 'snakecase' successfully unpacked and MD5 sums checked
# package 'janitor' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\deepa\AppData\Local\Temp\RtmpiKYtIr\downloaded_packages

# %%
library(here)
# Out:
# here() starts at C:/Deepankar/Placement-Prep

# %%
library(skimr)

# %%
library(janitor)
# Out:
# Attaching package: 'janitor'
#
#
# The following objects are masked from 'package:stats':
#
#     chisq.test, fisher.test

# %%
library(dplyr)

# %%
library(palmerpenguins)

# %%
skim_without_charts(penguins)
# Out:
# A skim_df: 8 × 14
#
# | <!--/--> | skim_type &lt;chr&gt; | skim_variable &lt;chr&gt; | n_missing &lt;int&gt; | complete_rate &lt;dbl&gt; | factor.ordered &lt;lgl&gt; | factor.n_unique &lt;int&gt; | factor.top_counts &lt;chr&gt; | numeric.mean &lt;dbl&gt; | numeric.sd &lt;dbl&gt; | numeric.p0 &lt;dbl&gt; | numeric.p25 &lt;dbl&gt; | numeric.p50 &lt;dbl&gt; | numeric.p75 &lt;dbl&gt; | numeric.p100 &lt;dbl&gt; |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|
# | 1 | factor  | species           |  0 | 1.0000000 | FALSE |  3 | Ade: 152, Gen: 124, Chi: 68 |         NA |          NA |     NA |       NA |      NA |     NA |     NA |
# | 2 | factor  | island            |  0 | 1.0000000 | FALSE |  3 | Bis: 168, Dre: 124, Tor: 52 |         NA |          NA |     NA |       NA |      NA |     NA |     NA |
# | 3 | factor  | sex               | 11 | 0.9680233 | FALSE |  2 | mal: 168, fem: 165          |         NA |          NA |     NA |       NA |      NA |     NA |     NA |
# ...

# %%
glimpse(penguins)
# Out:
# Rows: 344
# Columns: 8
# $ species           <fct> Adelie, Adelie, Adelie, Adelie, Adelie, Adelie, Adel~
# $ island            <fct> Torgersen, Torgersen, Torgersen, Torgersen, Torgerse~
# $ bill_length_mm    <dbl> 39.1, 39.5, 40.3, NA, 36.7, 39.3, 38.9, 39.2, 34.1, ~
# $ bill_depth_mm     <dbl> 18.7, 17.4, 18.0, NA, 19.3, 20.6, 17.8, 19.6, 18.1, ~
# $ flipper_length_mm <int> 181, 186, 195, NA, 193, 190, 181, 195, 193, 190, 186~
# $ body_mass_g       <int> 3750, 3800, 3250, NA, 3450, 3650, 3625, 4675, 3475, ~
# $ sex               <fct> male, female, female, NA, female, male, female, male~
# $ year              <int> 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007~

# %%
head(penguins)
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %%
penguins%>%
    select(species) # only the species column
# Out:
#     species
# 1   Adelie
# 2   Adelie
# 3   Adelie
# 4   Adelie
# 5   Adelie
# 6   Adelie
# 7   Adelie
# 8   Adelie
# 9   Adelie
# 10  Adelie
# 11  Adelie
# 12  Adelie
# 13  Adelie
# 14  Adelie
# 15  Adelie
# 16  Adelie
# 17  Adelie
# 18  Adelie
# 19  Adelie
# 20  Adelie
# 21  Adelie
# 22  Adelie
# 23  Adelie
# 24  Adelie
# 25  Adelie
# 26  Adelie
# 27  Adelie
# 28  Adelie
# 29  Adelie
# 30  Adelie
# ... ...
# 315 Chinstrap
# 316 Chinstrap
# 317 Chinstrap
# 318 Chinstrap
# 319 Chinstrap
# 320 Chinstrap
# 321 Chinstrap
# 322 Chinstrap
# 323 Chinstrap
# 324 Chinstrap
# 325 Chinstrap
# 326 Chinstrap
# 327 Chinstrap
# 328 Chinstrap
# 329 Chinstrap
# 330 Chinstrap
# 331 Chinstrap
# 332 Chinstrap
# 333 Chinstrap
# 334 Chinstrap
# 335 Chinstrap
# 336 Chinstrap
# 337 Chinstrap
# 338 Chinstrap
# 339 Chinstrap
# 340 Chinstrap
# 341 Chinstrap
# 342 Chinstrap
# 343 Chinstrap
# 344 Chinstrap

# %%
penguins %>%
    select(-species) # everything except the species column
# Out:
#     island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g sex
# 1   Torgersen 39.1           18.7          181               3750        male
# 2   Torgersen 39.5           17.4          186               3800        female
# 3   Torgersen 40.3           18.0          195               3250        female
# 4   Torgersen   NA             NA           NA                 NA        NA
# 5   Torgersen 36.7           19.3          193               3450        female
# 6   Torgersen 39.3           20.6          190               3650        male
# 7   Torgersen 38.9           17.8          181               3625        female
# 8   Torgersen 39.2           19.6          195               4675        male
# 9   Torgersen 34.1           18.1          193               3475        NA
# 10  Torgersen 42.0           20.2          190               4250        NA
# 11  Torgersen 37.8           17.1          186               3300        NA
# ...

# %%
penguins %>%
    rename(new_island= island) # rename the island column
# Out:
#     species   new_island bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Torgersen  39.1           18.7          181
# 2   Adelie    Torgersen  39.5           17.4          186
# 3   Adelie    Torgersen  40.3           18.0          195
# 4   Adelie    Torgersen    NA             NA           NA
# 5   Adelie    Torgersen  36.7           19.3          193
# 6   Adelie    Torgersen  39.3           20.6          190
# 7   Adelie    Torgersen  38.9           17.8          181
# 8   Adelie    Torgersen  39.2           19.6          195
# 9   Adelie    Torgersen  34.1           18.1          193
# 10  Adelie    Torgersen  42.0           20.2          190
# 11  Adelie    Torgersen  37.8           17.1          186
# 12  Adelie    Torgersen  37.8           17.3          180
# 13  Adelie    Torgersen  41.1           17.6          182
# 14  Adelie    Torgersen  38.6           21.2          191
# 15  Adelie    Torgersen  34.6           21.1          198
# ...

# %%
rename_with(penguins, toupper) # rename column names into uppercase
# Out:
#     SPECIES   ISLAND    BILL_LENGTH_MM BILL_DEPTH_MM FLIPPER_LENGTH_MM
# 1   Adelie    Torgersen 39.1           18.7          181
# 2   Adelie    Torgersen 39.5           17.4          186
# 3   Adelie    Torgersen 40.3           18.0          195
# 4   Adelie    Torgersen   NA             NA           NA
# 5   Adelie    Torgersen 36.7           19.3          193
# 6   Adelie    Torgersen 39.3           20.6          190
# 7   Adelie    Torgersen 38.9           17.8          181
# 8   Adelie    Torgersen 39.2           19.6          195
# 9   Adelie    Torgersen 34.1           18.1          193
# 10  Adelie    Torgersen 42.0           20.2          190
# 11  Adelie    Torgersen 37.8           17.1          186
# 12  Adelie    Torgersen 37.8           17.3          180
# 13  Adelie    Torgersen 41.1           17.6          182
# 14  Adelie    Torgersen 38.6           21.2          191
# 15  Adelie    Torgersen 34.6           21.1          198
# ...

# %%
rename_with(penguins, tolower) # rename column names into lowercase
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Torgersen 39.1           18.7          181
# 2   Adelie    Torgersen 39.5           17.4          186
# 3   Adelie    Torgersen 40.3           18.0          195
# 4   Adelie    Torgersen   NA             NA           NA
# 5   Adelie    Torgersen 36.7           19.3          193
# 6   Adelie    Torgersen 39.3           20.6          190
# 7   Adelie    Torgersen 38.9           17.8          181
# 8   Adelie    Torgersen 39.2           19.6          195
# 9   Adelie    Torgersen 34.1           18.1          193
# 10  Adelie    Torgersen 42.0           20.2          190
# 11  Adelie    Torgersen 37.8           17.1          186
# 12  Adelie    Torgersen 37.8           17.3          180
# 13  Adelie    Torgersen 41.1           17.6          182
# 14  Adelie    Torgersen 38.6           21.2          191
# 15  Adelie    Torgersen 34.6           21.1          198
# ...

# %%
clean_names(penguins)
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Torgersen 39.1           18.7          181
# 2   Adelie    Torgersen 39.5           17.4          186
# 3   Adelie    Torgersen 40.3           18.0          195
# 4   Adelie    Torgersen   NA             NA           NA
# 5   Adelie    Torgersen 36.7           19.3          193
# 6   Adelie    Torgersen 39.3           20.6          190
# 7   Adelie    Torgersen 38.9           17.8          181
# 8   Adelie    Torgersen 39.2           19.6          195
# 9   Adelie    Torgersen 34.1           18.1          193
# 10  Adelie    Torgersen 42.0           20.2          190
# 11  Adelie    Torgersen 37.8           17.1          186
# 12  Adelie    Torgersen 37.8           17.3          180
# 13  Adelie    Torgersen 41.1           17.6          182
# 14  Adelie    Torgersen 38.6           21.2          191
# 15  Adelie    Torgersen 34.6           21.1          198
# ...

# %%
library(tidyverse)
library(palmerpenguins)

# %%
penguins %>% arrange(bill_length_mm) # sort in ascending order
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Dream     32.1           15.5          188
# 2   Adelie    Dream     33.1           16.1          178
# 3   Adelie    Torgersen 33.5           19.0          190
# 4   Adelie    Dream     34.0           17.1          185
# 5   Adelie    Torgersen 34.1           18.1          193
# 6   Adelie    Torgersen 34.4           18.4          184
# 7   Adelie    Biscoe    34.5           18.1          187
# 8   Adelie    Torgersen 34.6           21.1          198
# 9   Adelie    Torgersen 34.6           17.2          189
# 10  Adelie    Biscoe    35.0           17.9          190
# 11  Adelie    Biscoe    35.0           17.9          192
# 12  Adelie    Torgersen 35.1           19.4          193
# 13  Adelie    Torgersen 35.2           15.9          186
# 14  Adelie    Biscoe    35.3           18.9          187
# 15  Adelie    Biscoe    35.5           16.2          195
# ...

# %%
penguins %>% arrange(-bill_length_mm) # sort in descending order
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Gentoo    Biscoe    59.6           17.0          230
# 2   Chinstrap Dream     58.0           17.8          181
# 3   Gentoo    Biscoe    55.9           17.0          228
# 4   Chinstrap Dream     55.8           19.8          207
# 5   Gentoo    Biscoe    55.1           16.0          230
# 6   Gentoo    Biscoe    54.3           15.7          231
# 7   Chinstrap Dream     54.2           20.8          201
# 8   Chinstrap Dream     53.5           19.9          205
# 9   Gentoo    Biscoe    53.4           15.8          219
# 10  Chinstrap Dream     52.8           20.0          205
# 11  Chinstrap Dream     52.7           19.8          197
# 12  Gentoo    Biscoe    52.5           15.6          221
# 13  Gentoo    Biscoe    52.2           17.1          228
# 14  Chinstrap Dream     52.2           18.8          197
# 15  Gentoo    Biscoe    52.1           17.0          230
# ...

# %%
penguins2 <- penguins %>% arrange(-bill_length_mm) # sort in descending order
View(penguins2)
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Gentoo    Biscoe    59.6           17.0          230
# 2   Chinstrap Dream     58.0           17.8          181
# 3   Gentoo    Biscoe    55.9           17.0          228
# 4   Chinstrap Dream     55.8           19.8          207
# 5   Gentoo    Biscoe    55.1           16.0          230
# 6   Gentoo    Biscoe    54.3           15.7          231
# 7   Chinstrap Dream     54.2           20.8          201
# 8   Chinstrap Dream     53.5           19.9          205
# 9   Gentoo    Biscoe    53.4           15.8          219
# 10  Chinstrap Dream     52.8           20.0          205
# 11  Chinstrap Dream     52.7           19.8          197
# 12  Gentoo    Biscoe    52.5           15.6          221
# 13  Gentoo    Biscoe    52.2           17.1          228
# 14  Chinstrap Dream     52.2           18.8          197
# 15  Gentoo    Biscoe    52.1           17.0          230
# ...

# %%
penguins %>%
    group_by(island) %>%
    drop_na() %>%
    summarise(mean_bill_length_mm = mean(bill_length_mm))
# Out:
#   island    mean_bill_length_mm
# 1 Biscoe    45.24847
# 2 Dream     44.22195
# 3 Torgersen 39.03830

# %%
penguins %>%
    group_by(island) %>%
    drop_na() %>%
    summarise(max_bill_length_mm = max(bill_length_mm))
# Out:
#   island    max_bill_length_mm
# 1 Biscoe    59.6
# 2 Dream     58.0
# 3 Torgersen 46.0

# %%
penguins %>%
    group_by(species, island) %>%
    drop_na() %>%
    summarise(mean_bill_length_mm = mean(bill_length_mm), max_bill_length_mm = max(bill_length_mm))
# Out:
# `summarise()` has grouped output by 'species'. You can override using the
# `.groups` argument.
#   species   island    mean_bill_length_mm max_bill_length_mm
# 1 Adelie    Biscoe    38.97500            45.6
# 2 Adelie    Dream     38.52000            44.1
# 3 Adelie    Torgersen 39.03830            46.0
# 4 Chinstrap Dream     48.83382            58.0
# 5 Gentoo    Biscoe    47.56807            59.6

# %%
penguins %>% filter(species== 'Adelie')
# Out:
#     species island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie  Torgersen 39.1           18.7          181
# 2   Adelie  Torgersen 39.5           17.4          186
# 3   Adelie  Torgersen 40.3           18.0          195
# 4   Adelie  Torgersen   NA             NA           NA
# 5   Adelie  Torgersen 36.7           19.3          193
# 6   Adelie  Torgersen 39.3           20.6          190
# 7   Adelie  Torgersen 38.9           17.8          181
# 8   Adelie  Torgersen 39.2           19.6          195
# 9   Adelie  Torgersen 34.1           18.1          193
# 10  Adelie  Torgersen 42.0           20.2          190
# 11  Adelie  Torgersen 37.8           17.1          186
# 12  Adelie  Torgersen 37.8           17.3          180
# 13  Adelie  Torgersen 41.1           17.6          182
# 14  Adelie  Torgersen 38.6           21.2          191
# 15  Adelie  Torgersen 34.6           21.1          198
# 16  Adelie  Torgersen 36.6           17.8          185
# ...

# %% [markdown]
# ### Transforning Data

# %%
id <- c(1:10)


name <- c("John Mendes", "Rob Stewart", "Rachel Abrahamson", "Christy Hickman", "Johnson Harper", "Candace Miller", "Carlson Landy", "Pansy Jordan", "Darius Berry", "Claudia Garcia")


job_title <- c("Professional", "Programmer", "Management", "Clerical", "Developer", "Programmer", "Management", "Clerical", "Developer", "Programmer")


employee <- data.frame(id, name, job_title)

# %%
employee
# Out:
#    id name              job_title
# 1   1 John Mendes       Professional
# 2   2 Rob Stewart       Programmer
# 3   3 Rachel Abrahamson Management
# 4   4 Christy Hickman   Clerical
# 5   5 Johnson Harper    Developer
# 6   6 Candace Miller    Programmer
# 7   7 Carlson Landy     Management
# 8   8 Pansy Jordan      Clerical
# 9   9 Darius Berry      Developer
# 10 10 Claudia Garcia    Programmer

# %%
library(tidyverse)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.3.2 --
# v ggplot2 3.4.1     v purrr   1.0.1
# v tibble  3.1.8     v dplyr   1.1.0
# v tidyr   1.3.0     v stringr 1.5.0
# v readr   2.1.4     v forcats 1.0.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
employee<- separate(employee, name, into = c('first_name', 'last_name'), sep = ' ')
employee
# Out:
#    id first_name last_name  job_title
# 1   1 John       Mendes     Professional
# 2   2 Rob        Stewart    Programmer
# 3   3 Rachel     Abrahamson Management
# 4   4 Christy    Hickman    Clerical
# 5   5 Johnson    Harper     Developer
# 6   6 Candace    Miller     Programmer
# 7   7 Carlson    Landy      Management
# 8   8 Pansy      Jordan     Clerical
# 9   9 Darius     Berry      Developer
# 10 10 Claudia    Garcia     Programmer

# %%
employee<- unite(employee, 'name', first_name, last_name, sep = ' ')
employee
# Out:
#    id name              job_title
# 1   1 John Mendes       Professional
# 2   2 Rob Stewart       Programmer
# 3   3 Rachel Abrahamson Management
# 4   4 Christy Hickman   Clerical
# 5   5 Johnson Harper    Developer
# 6   6 Candace Miller    Programmer
# 7   7 Carlson Landy     Management
# 8   8 Pansy Jordan      Clerical
# 9   9 Darius Berry      Developer
# 10 10 Claudia Garcia    Programmer

# %%
library(palmerpenguins)
head(penguins)
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %%
head(penguins%>%
    mutate(body_mass_kg = body_mass_g/1000, flipper_length_m= flipper_length_mm/1000))
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year body_mass_kg flipper_length_m
# 1 male   2007 3.75         0.181
# 2 female 2007 3.80         0.186
# 3 female 2007 3.25         0.195
# 4 NA     2007   NA            NA
# 5 female 2007 3.45         0.193
# 6 male   2007 3.65         0.190

# %% [markdown]
# ### Closer Look at the data

# %%
# install.packages('Tmisc')
# Out:
# package 'Tmisc' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\deepa\AppData\Local\Temp\RtmpgNMpQD\downloaded_packages

# %%
library(Tmisc)
data(quartet)
quartet
# Out:
#    set x  y
# 1  I   10  8.04
# 2  I    8  6.95
# 3  I   13  7.58
# 4  I    9  8.81
# 5  I   11  8.33
# 6  I   14  9.96
# 7  I    6  7.24
# 8  I    4  4.26
# 9  I   12 10.84
# 10 I    7  4.82
# 11 I    5  5.68
# 12 II  10  9.14
# 13 II   8  8.14
# 14 II  13  8.74
# 15 II   9  8.77
# 16 II  11  9.26
# 17 II  14  8.10
# 18 II   6  6.13
# 19 II   4  3.10
# 20 II  12  9.13
# 21 II   7  7.26
# 22 II   5  4.74
# 23 III 10  7.46
# 24 III  8  6.77
# 25 III 13 12.74
# 26 III  9  7.11
# 27 III 11  7.81
# 28 III 14  8.84
# 29 III  6  6.08
# 30 III  4  5.39
# 31 III 12  8.15
# 32 III  7  6.42
# 33 III  5  5.73
# 34 IV   8  6.58
# 35 IV   8  5.76
# 36 IV   8  7.71
# 37 IV   8  8.84
# 38 IV   8  8.47
# 39 IV   8  7.04
# 40 IV   8  5.25
# 41 IV  19 12.50
# 42 IV   8  5.56
# 43 IV   8  7.91
# 44 IV   8  6.89

# %%
# Anscombe's quartet ---> Four datasets that have nearly identical summary statistics

quartet %>%
    group_by(set) %>%
    summarise(mean = mean(x), sd(x), mean(y), sd(y), cor(x, y))
# Out:
#   set mean sd(x)    mean(y)  sd(y)    cor(x, y)
# 1 I   9    3.316625 7.500909 2.031568 0.8164205
# 2 II  9    3.316625 7.500909 2.031657 0.8162365
# 3 III 9    3.316625 7.500000 2.030424 0.8162867
# 4 IV  9    3.316625 7.500909 2.030579 0.8165214

# %%
ggplot(quartet, aes(x, y)) + geom_point() + geom_smooth(method = lm, se = FALSE) + facet_wrap(~set)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# install.packages('datasauRus')
# Out:
# package 'datasauRus' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\deepa\AppData\Local\Temp\RtmpgNMpQD\downloaded_packages

# %%
library(datasauRus)
ggplot(datasaurus_dozen, aes(x=x, y=y, colour= dataset)) + geom_point()+ theme_void()+ theme(legend.position = 'none')+ facet_wrap(~dataset, ncol = 3)
# Out:
# plot without title

# %% [markdown]
# ### Bias

# %%
# install.packages('SimDesign')
# Out:
# also installing the dependencies 'iterators', 'audio', 'globals', 'listenv', 'parallelly', 'foreach', 'sessioninfo', 'beepr', 'pbapply', 'RPushbullet', 'future', 'future.apply', 'progressr'
# package 'iterators' successfully unpacked and MD5 sums checked
# package 'audio' successfully unpacked and MD5 sums checked
# package 'globals' successfully unpacked and MD5 sums checked
# package 'listenv' successfully unpacked and MD5 sums checked
# package 'parallelly' successfully unpacked and MD5 sums checked
# package 'foreach' successfully unpacked and MD5 sums checked
# package 'sessioninfo' successfully unpacked and MD5 sums checked
# package 'beepr' successfully unpacked and MD5 sums checked
# package 'pbapply' successfully unpacked and MD5 sums checked
# package 'RPushbullet' successfully unpacked and MD5 sums checked
# package 'future' successfully unpacked and MD5 sums checked
# package 'future.apply' successfully unpacked and MD5 sums checked
# ...

# %%
library(SimDesign)

# %%
actual_tmp <- c(68.3, 70, 72.4, 71, 67, 70)
predicted_tmp <- c(67.9, 69, 71.5, 70, 67, 69)
bias(actual_tmp, predicted_tmp)
# Out:
# [1] 0.7166667
