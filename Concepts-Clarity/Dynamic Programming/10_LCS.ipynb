# %% [markdown]
# # **[Longest Common Subsequence](https://practice.geeksforgeeks.org/problems/longest-common-subsequence-1587115620/1?utm_source=geeksforgeeks&utm_medium=article_practice_tab&utm_campaign=article_practice_tab)**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **Recursion**

# %%
class Solution:
    
    #Function to find the length of longest common subsequence in two strings.
    def lcs(self,x,y,s1,s2):
        
        # code here
        if x==0 or y==0:
            return 0
        
        



s= Solution()
